# %%
import importlib.util
from pathlib import Path

spec = importlib.util.spec_from_file_location('fetch_bandcamp', Path('fetch-bandcamp.js'))
module = importlib.util.module_from_spec(spec)
spec.loader.exec_module(module)

html = Path('debug-drunkard.html').read_text()
albums = module.parseDrunkardAlbums(html)
print('count', len(albums))
for album in albums[:8]:
    print(album)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 5
#       2 from pathlib import Path
#       4 spec = importlib.util.spec_from_file_location('fetch_bandcamp', Path('fetch-bandcamp.js'))
# ----> 5 module = importlib.util.module_from_spec(spec)
#       6 spec.loader.exec_module(module)
#       8 html = Path('debug-drunkard.html').read_text()
#
# File <frozen importlib._bootstrap>:810, in module_from_spec(spec)
#
# AttributeError: 'NoneType' object has no attribute 'loader'
